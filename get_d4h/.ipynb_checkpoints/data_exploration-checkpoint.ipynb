# %% [markdown]
# # D4H Incident Data Exploration
#
# This notebook explores Search and Rescue incident data from D4H (Disaster4Help), loaded from `incidents.json`.
#
# ## Overview
# - Load and clean incident data using our custom data utilities
# - Perform exploratory data analysis
# - Visualize key patterns and insights

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
from datetime import datetime

# Import our custom data utilities
import data_utils

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %%
# Load and process the incidents data using our helper functions
print("Loading incidents data...")
df = data_utils.load_and_process_incidents('incidents.json')

print(f"Successfully loaded {len(df)} incidents")
print(f"Data shape: {df.shape}")
print(f"Date range: {df['startsAt'].min()} to {df['startsAt'].max()}")
# Out:
# Loading incidents data...
# Successfully loaded 937 incidents
# Data shape: (937, 46)
# Date range: 2018-10-06 18:30:00+00:00 to 2025-07-28 22:30:00+00:00

# %% [markdown]
# ## Data Exploration
#
# Let's explore the structure and content of our incident data.

# %%
# Descriptive statistics for numerical columns
print("=== NUMERICAL STATISTICS ===")
numerical_cols = df.select_dtypes(include=[np.number]).columns
display(df[numerical_cols].describe())

print("\n=== INCIDENT SUMMARY ===")
summary = data_utils.get_incident_summary(df)
for key, value in summary.items():
    print(f"{key}: {value}")

print("\n=== CATEGORICAL INSIGHTS ===")
if 'address.town' in df.columns:
    print(f"Top 5 towns by incident count:")
    print(df['address.town'].value_counts().head())

if 'night' in df.columns:
    print(f"\nDay vs Night incidents:")
    print(df['night'].value_counts())
# Out:
# === NUMERICAL STATISTICS ===
#           bearing   coordinator  countAttendance  countGuests      distance  \
# count  770.000000      4.000000       937.000000   937.000000  9.370000e+02
# mean   142.358442  14268.500000         9.927428     0.257204  4.991684e+04
# std     93.334689    161.411482        12.906512     2.932469  2.659871e+05
# min      0.000000  14130.000000         0.000000     0.000000  0.000000e+00
# 25%     66.000000  14130.750000         3.000000     0.000000  1.199500e+04
# 50%    112.000000  14253.000000         5.000000     0.000000  2.772300e+04
# 75%    227.000000  14390.750000        11.000000     0.000000  6.148100e+04
# max    359.000000  14438.000000        81.000000    70.000000  8.078811e+06
#
#                  id  percAttendance  weatherPressure  weatherCloudCover  \
# count  9.370000e+02      937.000000        30.000000          30.000000
# mean   6.087095e+05       68.067236      1016.796667           0.568333
# std    2.410099e+05       44.141608         7.227946           0.404723
# min    3.230700e+05        0.000000      1002.060000           0.000000
# 25%    4.285300e+05        9.000000      1012.777500           0.092500
# 50%    5.278090e+05      100.000000      1017.930000           0.710000
# 75%    7.283960e+05      100.000000      1020.257500           0.967500
# max    1.259663e+06      100.000000      1035.120000           1.000000
#
#        owner.id  locationBookmark.id    latitude   longitude
# count     937.0            75.000000  937.000000  937.000000
# mean     1516.0          3323.840000   39.865833 -101.111513
# std         0.0            69.747429   17.904219   46.163677
# min      1516.0          3254.000000    0.000000 -124.366608
# 25%      1516.0          3311.000000   47.443322 -122.078160
# 50%      1516.0          3316.000000   47.866847 -121.664652
# 75%      1516.0          3316.000000   48.070252 -121.141500
# max      1516.0          3655.000000   48.889692  135.750000
# === INCIDENT SUMMARY ===
# total_incidents: 937
# date_range: {'earliest': Timestamp('2018-10-06 18:30:00+0000', tz='UTC'), 'latest': Timestamp('2025-07-28 22:30:00+0000', tz='UTC')}
# attendance_stats: {'mean': np.float64(9.92742796157951), 'median': np.float64(5.0), 'max': np.int64(81)}
# location_coverage: {'unique_towns': 110, 'unique_regions': 2}
#
# === CATEGORICAL INSIGHTS ===
# Top 5 towns by incident count:
# address.town
#                  219
# Granite Falls     91
# Gold Bar          78
# Darrington        68
# Arlington         51
# Name: count, dtype: int64
#
# Day vs Night incidents:
# night
# True     780
# False    157
# Name: count, dtype: int64

# %%
# Data overview and structure
print("=== DATASET OVERVIEW ===")
print(f"Shape: {df.shape}")
print(f"Memory usage: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

print("\n=== COLUMN INFORMATION ===")
df.info()

print("\n=== MISSING VALUES ===")
missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(1)
missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing %': missing_pct
}).sort_values('Missing Count', ascending=False)
print(missing_df[missing_df['Missing Count'] > 0].head(10))
# Out:
# === DATASET OVERVIEW ===
# Shape: (937, 46)
# Memory usage: 1.66 MB
#
# === COLUMN INFORMATION ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 937 entries, 0 to 936
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   bearing                        770 non-null    float64
#  1   coordinator                    4 non-null      float64
#  2   countAttendance                937 non-null    int64
#  3   countGuests                    937 non-null    int64
#  4   createdAt                      937 non-null    datetime64[ns, UTC]
#  5   createdOrPublishedAt           937 non-null    datetime64[ns, UTC]
#  6   description                    937 non-null    object
#  7   distance                       937 non-null    int64
#  8   id                             937 non-null    int64
#  9   night                          937 non-null    bool
#  10  percAttendance                 937 non-null    int64
#  11  plan                           0 non-null      object
#  12  published                      937 non-null    bool
#  13  selfCoordinator                937 non-null    bool
#  14  shared                         937 non-null    bool
#  15  trackingNumber                 0 non-null      object
#  16  updatedAt                      937 non-null    datetime64[ns, UTC]
#  17  descriptionDeprecated          553 non-null    object
#  18  planDeprecated                 0 non-null      object
#  19  weatherPressure                30 non-null     float64
#  20  weatherCloudCover              30 non-null     float64
#  21  customFieldValues              937 non-null    object
#  22  resourceType                   937 non-null    object
#  23  startsAt                       937 non-null    datetime64[ns, UTC]
#  24  endsAt                         937 non-null    datetime64[ns, UTC]
#  25  approved                       937 non-null    bool
#  26  fullTeam                       937 non-null    bool
#  27  reference                      937 non-null    object
#  28  referenceDescription           937 non-null    object
#  29  tags                           937 non-null    object
#  30  owner.resourceType             937 non-null    object
#  31  owner.id                       937 non-null    int64
#  32  location.type                  937 non-null    object
#  33  location.coordinates           937 non-null    object
#  34  weather.symbol                 0 non-null      object
#  35  weather.symbolDate             0 non-null      object
#  36  weather.temperature            0 non-null      object
#  37  address.postcode               937 non-null    object
#  38  address.region                 937 non-null    object
#  39  address.street                 937 non-null    object
#  40  address.town                   937 non-null    object
#  41  address.country                937 non-null    object
#  42  locationBookmark.resourceType  937 non-null    object
#  43  locationBookmark.id            75 non-null     float64
#  44  latitude                       937 non-null    float64
#  45  longitude                      937 non-null    float64
# dtypes: bool(6), datetime64[ns, UTC](5), float64(7), int64(6), object(22)
# memory usage: 298.4+ KB
#
# === MISSING VALUES ===
#                      Missing Count  Missing %
# plan                           937      100.0
# weather.symbol                 937      100.0
# weather.symbolDate             937      100.0
# weather.temperature            937      100.0
# planDeprecated                 937      100.0
# trackingNumber                 937      100.0
# coordinator                    933       99.6
# weatherPressure                907       96.8
# weatherCloudCover              907       96.8
# locationBookmark.id            862       92.0

# %%
# Display the first few rows of the cleaned data
print("First 5 incidents:")
display(df.head())

print("\nColumn names and types:")
print(df.dtypes)
# Out:
# First 5 incidents:
#    bearing  coordinator  countAttendance  countGuests  \
# 0     78.0          NaN                4            0
# 1     61.0          NaN                5            0
# 2    209.0          NaN               33            0
# 3    314.0      14131.0                4            0
# 4     72.0          NaN               12            0
#
#                   createdAt      createdOrPublishedAt  \
# 0 2019-07-29 08:21:14+00:00 2018-12-18 22:15:18+00:00
# 1 2019-07-29 08:21:14+00:00 2019-03-04 01:43:56+00:00
# 2 2019-07-29 08:21:14+00:00 2018-12-19 22:01:52+00:00
# 3 2019-07-29 08:21:14+00:00 2019-01-27 20:12:53+00:00
# 4 2019-07-29 08:21:14+00:00 2019-06-20 18:37:41+00:00
#
#                                          description  distance      id  night  \
# 0                                                        80594  323070   True
# 1  K9 &amp; Tracking Team members and SAR Deputie...     52304  331276   True
# 2  55 YO Steve Linn Missing since 2:30 PM 11/30/1...     13262  329500   True
# 3  Tulalip PD requested assistance searching for ...     19448  340525   True
# 4  Reported yelling for 911 callWitness was named...     44234  336581   True
#
#    percAttendance  plan  published  selfCoordinator  shared trackingNumber  \
# 0             100  None       True            False   False           None
# 1             100  None       True            False   False           None
# 2             100  None       True             True   False           None
# 3             100  None       True            False   False           None
# 4               7  None       True            False   False           None
#
#                   updatedAt  \
# 0 2023-02-13 17:56:30+00:00
# 1 2023-02-13 17:56:30+00:00
# 2 2023-02-13 17:57:17+00:00
# 3 2023-02-13 17:56:30+00:00
# 4 2023-02-13 17:57:17+00:00
#
#                                descriptionDeprecated planDeprecated  \
# 0                                                              None
# 1  K9 &amp; Tracking Team members and SAR Deputie...           None
# 2  55 YO Steve Linn Missing since 2:30 PM 11/30/1...           None
# 3  Tulalip PD requested assistance searching for ...           None
# 4  Reported yelling for 911 call\n\nWitness was n...           None
#
#    weatherPressure  weatherCloudCover  \
# 0              NaN                NaN
# 1              NaN                NaN
# 2              NaN                NaN
# 3              NaN                NaN
# 4              NaN                NaN
#
#                                    customFieldValues resourceType  \
# 0                                                 []     Incident
# 1  [{'customField': {'owner': {'resourceType': 'T...     Incident
# 2  [{'customField': {'owner': {'resourceType': 'T...     Incident
# 3  [{'customField': {'owner': {'resourceType': 'T...     Incident
# 4  [{'customField': {'owner': {'resourceType': 'T...     Incident
#
#                    startsAt                    endsAt  approved  fullTeam  \
# 0 2018-10-06 18:30:00+00:00 2018-10-06 22:15:00+00:00      True     False
# 1 2018-11-14 02:45:00+00:00 2018-11-14 22:00:00+00:00     False     False
# 2 2018-12-01 00:30:00+00:00 2018-12-01 04:30:00+00:00      True      True
# 3 2018-12-27 01:50:00+00:00 2018-12-27 06:00:00+00:00      True     False
# 4 2019-01-06 01:30:00+00:00 2019-01-06 07:30:00+00:00      True      True
#
#   reference                             referenceDescription  \
# 0     00014                SH10 Search for missing PCT Hiker
# 1     18223  18-4308 Beaver Lake body recover off Mtn Lp Hwy
# 2      4500               Bothell Missing Person 2018-170395
# 3     19079                             Assist to Tulalip PD
# 4   19-0014               2019-01-05 Big Four SCSO 2019-2403
#
#                                                 tags owner.resourceType  \
# 0                                                 []               Team
# 1  [{'id': 23682, 'resourceType': 'Tag'}, {'id': ...               Team
# 2  [{'id': 23836, 'resourceType': 'Tag'}, {'id': ...               Team
# 3  [{'id': 23785, 'resourceType': 'Tag'}, {'id': ...               Team
# 4  [{'id': 23838, 'resourceType': 'Tag'}, {'id': ...               Team
#
#    owner.id location.type                          location.coordinates  \
# 0      1516         Point  [48.0888156678010000, -121.0154986381500000]
# 1      1516         Point  [48.1719434229920000, -121.4599908952500000]
# 2      1516         Point  [47.8428304485340000, -122.1645355224600000]
# 3      1516         Point  [48.0705662045290000, -122.2633266449000000]
# 4      1516         Point  [48.0659000000000000, -121.5107000000000000]
#
#   weather.symbol weather.symbolDate weather.temperature address.postcode  \
# 0           None               None                None            98241
# 1           None               None                None            98241
# 2           None               None                None            98012
# 3           None               None                None            98271
# 4           None               None                None            98252
#
#   address.region          address.street              address.town  \
# 0     Washington                                        Darrington
# 1     Washington       Mountain Loop Hwy                Darrington
# 2     Washington  4977 W Interurban Blvd  Seattle Hill-Silver Firs
# 3     Washington            2220 Turk Dr                Marysville
# 4     Washington                                     Granite Falls
#
#   address.country locationBookmark.resourceType  locationBookmark.id  \
# 0   United States              LocationBookmark                  NaN
# 1   United States              LocationBookmark                  NaN
# 2   United States              LocationBookmark                  NaN
# 3   United States              LocationBookmark                  NaN
# 4   United States              LocationBookmark                  NaN
#
#     latitude   longitude
# 0  48.088816 -121.015499
# 1  48.171943 -121.459991
# 2  47.842830 -122.164536
# 3  48.070566 -122.263327
# 4  48.065900 -121.510700
# Column names and types:
# bearing                                      float64
# coordinator                                  float64
# countAttendance                                int64
# countGuests                                    int64
# createdAt                        datetime64[ns, UTC]
# createdOrPublishedAt             datetime64[ns, UTC]
# description                                   object
# distance                                       int64
# id                                             int64
# night                                           bool
# percAttendance                                 int64
# plan                                          object
# published                                       bool
# selfCoordinator                                 bool
# shared                                          bool
# trackingNumber                                object
# updatedAt                        datetime64[ns, UTC]
# descriptionDeprecated                         object
# planDeprecated                                object
# weatherPressure                              float64
# weatherCloudCover                            float64
# customFieldValues                             object
# resourceType                                  object
# startsAt                         datetime64[ns, UTC]
# endsAt                           datetime64[ns, UTC]
# approved                                        bool
# fullTeam                                        bool
# reference                                     object
# referenceDescription                          object
# tags                                          object
# owner.resourceType                            object
# owner.id                                       int64
# location.type                                 object
# location.coordinates                          object
# weather.symbol                                object
# weather.symbolDate                            object
# weather.temperature                           object
# address.postcode                              object
# address.region                                object
# address.street                                object
# address.town                                  object
# address.country                               object
# locationBookmark.resourceType                 object
# locationBookmark.id                          float64
# latitude                                     float64
# longitude                                    float64
# dtype: object

# %%
# Verify data cleaning results
print("=== DATA CLEANING VERIFICATION ===")

# Check if coordinates were properly parsed
if 'latitude' in df.columns and 'longitude' in df.columns:
    print("✓ Coordinates successfully parsed")
    print(f"  Latitude range: {df['latitude'].min():.4f} to {df['latitude'].max():.4f}")
    print(f"  Longitude range: {df['longitude'].min():.4f} to {df['longitude'].max():.4f}")
else:
    print("✗ Coordinates not found")

# Check date parsing
date_cols = ['createdAt', 'startsAt', 'endsAt']
for col in date_cols:
    if col in df.columns:
        print(f"✓ {col}: {df[col].dtype}")
    else:
        print(f"✗ {col}: not found")

# Check for HTML in descriptions
if 'description' in df.columns:
    html_count = df['description'].str.contains('<.*>', regex=True, na=False).sum()
    print(f"HTML tags in descriptions: {html_count} (should be 0 after cleaning)")
# Out:
# === DATA CLEANING VERIFICATION ===
# ✓ Coordinates successfully parsed
#   Latitude range: 0.0000 to 48.8897
#   Longitude range: -124.3666 to 135.7500
# ✓ createdAt: datetime64[ns, UTC]
# ✓ startsAt: datetime64[ns, UTC]
# ✓ endsAt: datetime64[ns, UTC]
# HTML tags in descriptions: 0 (should be 0 after cleaning)

# %% [markdown]
# ## Temporal Analysis
#
# Let's analyze incident patterns over time.

# %%
# Temporal analysis
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Incident Temporal Patterns', fontsize=16)

# Incidents by year
if 'startsAt' in df.columns:
    df['year'] = df['startsAt'].dt.year
    yearly_counts = df['year'].value_counts().sort_index()
    
    axes[0,0].bar(yearly_counts.index, yearly_counts.values)
    axes[0,0].set_title('Incidents by Year')
    axes[0,0].set_xlabel('Year')
    axes[0,0].set_ylabel('Number of Incidents')
    axes[0,0].tick_params(axis='x', rotation=45)

# Incidents by month
if 'startsAt' in df.columns:
    df['month'] = df['startsAt'].dt.month
    monthly_counts = df['month'].value_counts().sort_index()
    
    axes[0,1].bar(monthly_counts.index, monthly_counts.values)
    axes[0,1].set_title('Incidents by Month')
    axes[0,1].set_xlabel('Month')
    axes[0,1].set_ylabel('Number of Incidents')

# Incidents by day of week
if 'startsAt' in df.columns:
    df['day_of_week'] = df['startsAt'].dt.day_name()
    day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    day_counts = df['day_of_week'].value_counts().reindex(day_order)
    
    axes[1,0].bar(range(len(day_counts)), day_counts.values)
    axes[1,0].set_title('Incidents by Day of Week')
    axes[1,0].set_xlabel('Day of Week')
    axes[1,0].set_ylabel('Number of Incidents')
    axes[1,0].set_xticks(range(len(day_counts)))
    axes[1,0].set_xticklabels(day_counts.index, rotation=45)

# Incidents by hour
if 'startsAt' in df.columns:
    df['hour'] = df['startsAt'].dt.hour
    hourly_counts = df['hour'].value_counts().sort_index()
    
    axes[1,1].bar(hourly_counts.index, hourly_counts.values)
    axes[1,1].set_title('Incidents by Hour of Day')
    axes[1,1].set_xlabel('Hour')
    axes[1,1].set_ylabel('Number of Incidents')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Geographical Analysis
#
# Explore the spatial distribution of incidents.

# %%
# Geographical analysis
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Geographical Distribution of Incidents', fontsize=16)

# Top locations by incident count
if 'address.town' in df.columns:
    top_towns = df['address.town'].value_counts().head(10)
    axes[0].barh(range(len(top_towns)), top_towns.values)
    axes[0].set_yticks(range(len(top_towns)))
    axes[0].set_yticklabels(top_towns.index)
    axes[0].set_title('Top 10 Towns by Incident Count')
    axes[0].set_xlabel('Number of Incidents')

# Distance distribution
if 'distance' in df.columns:
    # Remove outliers for better visualization
    q99 = df['distance'].quantile(0.99)
    distance_filtered = df[df['distance'] <= q99]['distance']
    
    axes[1].hist(distance_filtered, bins=50, alpha=0.7, edgecolor='black')
    axes[1].set_title('Distribution of Incident Distances')
    axes[1].set_xlabel('Distance (meters)')
    axes[1].set_ylabel('Frequency')

# Scatter plot of coordinates (if available)
if 'latitude' in df.columns and 'longitude' in df.columns:
    valid_coords = df.dropna(subset=['latitude', 'longitude'])
    axes[2].scatter(valid_coords['longitude'], valid_coords['latitude'], 
                   alpha=0.6, s=20)
    axes[2].set_title('Incident Locations')
    axes[2].set_xlabel('Longitude')
    axes[2].set_ylabel('Latitude')
    axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print geographical summary
print("=== GEOGRAPHICAL SUMMARY ===")
if 'address.town' in df.columns:
    print(f"Number of unique towns: {df['address.town'].nunique()}")
    # Filter out rows with missing or empty town values
    towns_with_name = df[df['address.town'].notna() & (df['address.town'].str.strip() != "")]
    if not towns_with_name.empty:
        print(f"Most incidents in: {towns_with_name['address.town'].mode().iloc[0]}")
    else:
        print("No valid town data available.")

if 'distance' in df.columns:
    print(f"Average distance: {df['distance'].mean():.0f} meters")
    print(f"Max distance: {df['distance'].max():.0f} meters")
# Out:
# === GEOGRAPHICAL SUMMARY ===
# Number of unique towns: 110
# Most incidents in: Granite Falls
# Average distance: 49917 meters
# Max distance: 8078811 meters

# %% [markdown]
# ## Interactive Heatmap
#
# Let's create an interactive heatmap of incident locations using Folium to visualize the geographic density of Search and Rescue incidents.

# %%
# Create interactive heatmap using Folium
if 'latitude' in df.columns and 'longitude' in df.columns:
    # Filter out rows with valid coordinates
    valid_coords_df = df.dropna(subset=['latitude', 'longitude']).copy()
    
    print(f"Creating maps with {len(valid_coords_df)} incidents that have coordinates")
    
    if len(valid_coords_df) > 0:
        # Taylor's Landing coordinates (home base)
        taylors_landing_lat = 47.94964
        taylors_landing_lon = -122.077301
        
        print(f"Map centered on Taylor's Landing: {taylors_landing_lat}, {taylors_landing_lon}")
        
        # === HEATMAP ===
        # Create base map centered on Taylor's Landing
        heatmap = folium.Map(
            location=[taylors_landing_lat, taylors_landing_lon],
            zoom_start=9,
            tiles='OpenStreetMap'
        )
        
        # Add Taylor's Landing marker
        folium.Marker(
            location=[taylors_landing_lat, taylors_landing_lon],
            popup=folium.Popup("<b>Taylor's Landing</b><br>SAR Home Base", max_width=200),
            icon=folium.Icon(color='green', icon='home', prefix='fa')
        ).add_to(heatmap)
        
        # Prepare data for heatmap - list of [lat, lon] pairs
        heat_data = [[row['latitude'], row['longitude']] for _, row in valid_coords_df.iterrows()]
        
        # Add heatmap layer
        HeatMap(
            heat_data,
            min_opacity=0.3,
            max_zoom=18,
            radius=17,
            blur=15,
            gradient={
            0.1: 'blue',
            0.3: 'lime',
            0.5: 'yellow',
            0.7: 'orange',
            0.8: 'red'
            }
        ).add_to(heatmap)
        
        # Add layer control
        folium.LayerControl().add_to(heatmap)
        
        print("📍 Incident Density Heatmap:")
        display(heatmap)
        
        # === INCIDENT POINTS MAP ===
        # Create second map for individual incident markers
        incidents_map = folium.Map(
            location=[taylors_landing_lat, taylors_landing_lon],
            zoom_start=9,
            tiles='CartoDB positron'
        )
        
        # Add Taylor's Landing marker
        folium.Marker(
            location=[taylors_landing_lat, taylors_landing_lon],
            popup=folium.Popup("<b>Taylor's Landing</b><br>SAR Home Base", max_width=200),
            icon=folium.Icon(color='green', icon='home', prefix='fa')
        ).add_to(incidents_map)
        
        # Add all incident markers
        for _, incident in valid_coords_df.iterrows():
            # Create popup text with incident details
            popup_text = f"""
            <b>Incident:</b> {incident.get('referenceDescription', 'N/A')}<br>
            <b>Date:</b> {str(incident.get('startsAt', 'N/A'))[:10]}<br>
            <b>Town:</b> {incident.get('address.town', 'N/A')}<br>
            <b>Attendance:</b> {incident.get('countAttendance', 'N/A')} people<br>
            <b>Night:</b> {'Yes' if incident.get('night', False) else 'No'}<br>
            <b>Distance:</b> {incident.get('distance', 'N/A')} meters
            """
            
            # Color code by night/day
            color = 'darkblue' if incident.get('night', False) else 'orange'
            fillColor = 'blue' if incident.get('night', False) else 'yellow'
            
            folium.CircleMarker(
                location=[incident['latitude'], incident['longitude']],
                radius=4,
                popup=folium.Popup(popup_text, max_width=300),
                color=color,
                fillColor=fillColor,
                fillOpacity=0.7,
                weight=2
            ).add_to(incidents_map)
        
        # Add layer control
        folium.LayerControl().add_to(incidents_map)
        
        print(f"\n🗺️ Individual Incident Locations ({len(valid_coords_df)} incidents):")
        print("Blue markers = Night incidents, Yellow markers = Day incidents")
        display(incidents_map)
        
    else:
        print("No valid coordinates found for maps")
else:
    print("Latitude and longitude columns not found")
# Out:
# Creating maps with 937 incidents that have coordinates
# Map centered on Taylor's Landing: 47.94964, -122.077301
# 📍 Incident Density Heatmap:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba11f008c263f0b57864f4db49a68dff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba11f008c263f0b57864f4db49a68dff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba11f008c263f0b57864f4db49a68dff = L.map(
#                 &quot;map_ba11f008c263f0b57864f4db49a68dff&quot;,
#                 {
#                     center: [47.94964, -122.077301],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce3301d41f8e9ffbc4d4736e66e4663b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce3301d41f8e9ffbc4d4736e66e4663b.addTo(map_ba11f008c263f0b57864f4db49a68dff);
#
#
#             var marker_c9b8d96323a0517e55ac2b9018fcd4f2 = L.marker(
#                 [47.94964, -122.077301],
#                 {
# }
#             ).addTo(map_ba11f008c263f0b57864f4db49a68dff);
#
#
#             var icon_d21f5504d8f8cf2fbdf53dcf50e09e50 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dc7f65425dddd69e309282849832156c = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_df739aa503e24172cacce24108fbe621 = $(`&lt;div id=&quot;html_df739aa503e24172cacce24108fbe621&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Taylor&#x27;s Landing&lt;/b&gt;&lt;br&gt;SAR Home Base&lt;/div&gt;`)[0];
#                 popup_dc7f65425dddd69e309282849832156c.setContent(html_df739aa503e24172cacce24108fbe621);
#
#
#
#         marker_c9b8d96323a0517e55ac2b9018fcd4f2.bindPopup(popup_dc7f65425dddd69e309282849832156c)
#         ;
#
#
#
#
#                 marker_c9b8d96323a0517e55ac2b9018fcd4f2.setIcon(icon_d21f5504d8f8cf2fbdf53dcf50e09e50);
#
#
#             var heat_map_baab241c683ac949bdea2ed2fb750f3a = L.heatLayer(
#                 [[48.088815667801, -121.01549863815], [48.171943422992, -121.45999089525], [47.842830448534, -122.16453552246], [48.070566204529, -122.2633266449], [48.0659, -121.5107], [48.069282907565, -121.70894622803], [47.888151431943, -122.29506103801], [48.05725, -121.66418], [47.815795967014, -121.29631519318], [47.826105252606, -122.2557081328], [47.863127885022, -121.66264057159], [47.88815143194284, -122.2950610380127], [48.077362126433, -121.93268537521], [47.886465398678, -122.17645908543], [47.57266661726, -120.6054167108], [47.851806414898, -121.30884647369], [47.794346179679, -122.21680104733], [48.08476815725101, -121.78533554077148], [47.947095711091, -122.07815982085], [48.241938514013, -122.33001708984], [47.849531728179, -122.25430186937], [47.864875889578, -121.68109432648], [47.808390177984, -121.83131807297], [47.862950183631, -121.30704402924], [48.178105839109, -121.35918617249], [47.799780399006, -122.33345031738], [48.07022208334323, -121.65324211120605], [47.864965596601, -121.6808795929], [47.850079126647, -122.27580979388], [47.892113396408, -122.16760396957], [47.809546961259, -121.64991617203], [48.142089577887, -121.42212774006], [47.860627862864, -121.66551589966], [47.813548749754, -122.28232681621], [47.927711418289, -121.3383936882], [47.86062992178047, -121.66552187171146], [47.880216, -122.18536445981], [48.097212458016045, -121.7973194748688], [47.796344121022, -121.56723118934], [47.77788100872986, -122.34542138803147], [47.330917368579, -120.66895537328], [48.109933165132745, -121.85666084289551], [48.674101644848, -121.26691818237], [47.86068544975889, -121.66422843933105], [46.760019482688, -122.03835413642], [48.097212458016, -121.79731947487], [47.860542451813, -121.66465208454], [0.0, 0.0], [48.022309440449, -121.35635375977], [48.061446215624, -121.76559448242], [47.330919508454, -120.6689547092], [47.820531867461, -121.52526855469], [47.947095711091, -122.07815982085], [46.8751, -121.76962], [48.0543, -121.6635], [48.110127523372, -122.28027278559], [47.942257493219, -122.13151183236], [47.845660300167, -122.23813533783], [48.066637350834, -121.76198959351], [48.1999877046, -122.17744088845], [48.002584065390124, -121.66969620622694], [48.05429570432, -121.66350381427], [47.801857904236, -121.54198743534], [46.80701137659, -121.73988819122], [48.055824285425, -1
# 🗺️ Individual Incident Locations (937 incidents):
# Blue markers = Night incidents, Yellow markers = Day incidents
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ab853442ac6244361bc6021efe7c026 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ab853442ac6244361bc6021efe7c026&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ab853442ac6244361bc6021efe7c026 = L.map(
#                 &quot;map_7ab853442ac6244361bc6021efe7c026&quot;,
#                 {
#                     center: [47.94964, -122.077301],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40c5a7f48603234b0406978bc016393a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40c5a7f48603234b0406978bc016393a.addTo(map_7ab853442ac6244361bc6021efe7c026);
#
#
#             var marker_a4b866205fb4f39bb527ddf1293f6266 = L.marker(
#                 [47.94964, -122.077301],
#                 {
# }
#             ).addTo(map_7ab853442ac6244361bc6021efe7c026);
#
#
#             var icon_77e0014b5325fa83814920592bde5712 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b906f644844097f53a8b17abeb83a2a0 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_88ea85ade2b2a692cfa6f61d6838f85e = $(`&lt;div id=&quot;html_88ea85ade2b2a692cfa6f61d6838f85e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Taylor&#x27;s Landing&lt;/b&gt;&lt;br&gt;SAR Home Base&lt;/div&gt;`)[0];
#                 popup_b906f644844097f53a8b17abeb83a2a0.setContent(html_88ea85ade2b2a692cfa6f61d6838f85e);
#
#
#
#         marker_a4b866205fb4f39bb527ddf1293f6266.bindPopup(popup_b906f644844097f53a8b17abeb83a2a0)
#         ;
#
#
#
#
#                 marker_a4b866205fb4f39bb527ddf1293f6266.setIcon(icon_77e0014b5325fa83814920592bde5712);
#
#
#             var circle_marker_d1e578575b71a68700a955271b5e1254 = L.circleMarker(
#                 [48.088815667801, -121.01549863815],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_7ab853442ac6244361bc6021efe7c026);
#
#
#         var popup_880ad72c3ebb23eb8b94dc02b99565a7 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_31128202cd6685d01bede59b69b937f5 = $(`&lt;div id=&quot;html_31128202cd6685d01bede59b69b937f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;b&gt;Incident:&lt;/b&gt; SH10 Search for missing PCT Hiker&lt;br&gt;             &lt;b&gt;Date:&lt;/b&gt; 2018-10-06&lt;br&gt;             &lt;b&gt;Town:&lt;/b&gt; Darrington&lt;br&gt;             &lt;b&gt;Attendance:&lt;/b&gt; 4 people&lt;br&gt;             &lt;b&gt;Night:&lt;/b&gt; Yes&lt;br&gt;             &lt;b&gt;Distance:&lt;/b&gt; 80594 meters             &lt;/div&gt;`)[0];
#                 popup_880ad72c3ebb23eb8b94dc02b99565a7.setContent(html_31128202cd6685d01bede59b69b937f5);
#
#
#
#         circle_marker_d1e578575b71a68700a955271b5e1254.bindPopup(popup_880ad72c3ebb23eb8b94dc02b99565a7)
#         ;
#
#
#
#
#             var circle_marker_29156995f654fec077f99576eb05c231 = L.circleMarker(
#                 [48.171943422992, -121.45999089525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_7ab853442ac6244361bc6021efe7c026);
#
#
#         var popup_314e98e6b1009b50e32cbda2ef55f234 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Summary and Key Insights
#
# Based on our analysis of the D4H incident data, here are the key findings:

# %%
# Generate summary insights
print("🔍 KEY INSIGHTS FROM D4H INCIDENT DATA ANALYSIS")
print("=" * 60)

# Data overview
print(f"📊 DATASET OVERVIEW:")
print(f"   • Total incidents analyzed: {len(df):,}")
print(f"   • Date range: {df['startsAt'].min().strftime('%Y-%m-%d')} to {df['startsAt'].max().strftime('%Y-%m-%d')}")
print(f"   • Geographic coverage: {df['address.town'].nunique()} towns across {df['address.region'].nunique()} regions")

# Temporal patterns
print(f"\n⏰ TEMPORAL PATTERNS:")
if 'night' in df.columns:
    night_pct = (df['night'].sum() / len(df) * 100)
    print(f"   • {night_pct:.1f}% of incidents occur at night")

if 'year' in df.columns:
    peak_year = df['year'].mode().iloc[0]
    peak_count = df['year'].value_counts().iloc[0]
    print(f"   • Peak incident year: {peak_year} ({peak_count} incidents)")

if 'month' in df.columns:
    peak_month = df['month'].mode().iloc[0]
    month_names = ['', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                   'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    print(f"   • Most active month: {month_names[peak_month]}")

# Geographic patterns
print(f"\n🗺️ GEOGRAPHIC PATTERNS:")
if 'address.town' in df.columns:
    # Filter out empty/missing town names
    towns_with_data = df[df['address.town'].notna() & (df['address.town'].str.strip() != "")]
    if not towns_with_data.empty:
        top_town = towns_with_data['address.town'].mode().iloc[0]
        top_count = towns_with_data['address.town'].value_counts().iloc[0]
        print(f"   • Highest incident town: {top_town} ({top_count} incidents)")

if 'distance' in df.columns:
    avg_distance = df['distance'].mean()
    max_distance = df['distance'].max()
    print(f"   • Average incident distance: {avg_distance:.0f} meters")
    print(f"   • Maximum incident distance: {max_distance:.0f} meters")

# Team response patterns
print(f"\n👥 TEAM RESPONSE PATTERNS:")
if 'countAttendance' in df.columns:
    avg_attendance = df['countAttendance'].mean()
    max_attendance = df['countAttendance'].max()
    print(f"   • Average team size: {avg_attendance:.1f} people")
    print(f"   • Largest response: {max_attendance} people")

if 'percAttendance' in df.columns:
    avg_attendance_pct = df['percAttendance'].mean()
    print(f"   • Average attendance rate: {avg_attendance_pct:.1f}%")

# Data quality
print(f"\n✅ DATA QUALITY:")
coord_coverage = len(df.dropna(subset=['latitude', 'longitude'])) / len(df) * 100
print(f"   • Geographic coordinate coverage: {coord_coverage:.1f}%")

missing_descriptions = df['description'].isna().sum()
print(f"   • Incidents with descriptions: {len(df) - missing_descriptions:,} ({(len(df) - missing_descriptions)/len(df)*100:.1f}%)")

print(f"\n💡 The interactive heatmap above shows the geographic distribution of incidents,")
print(f"   with red areas indicating higher concentrations of Search and Rescue activity.")
print("=" * 60)
# Out:
# 🔍 KEY INSIGHTS FROM D4H INCIDENT DATA ANALYSIS
# ============================================================
# 📊 DATASET OVERVIEW:
#    • Total incidents analyzed: 937
#    • Date range: 2018-10-06 to 2025-07-28
#    • Geographic coverage: 110 towns across 2 regions
#
# ⏰ TEMPORAL PATTERNS:
#    • 83.2% of incidents occur at night
#    • Peak incident year: 2024 (168 incidents)
#    • Most active month: Jul
#
# 🗺️ GEOGRAPHIC PATTERNS:
#    • Highest incident town: Granite Falls (91 incidents)
#    • Average incident distance: 49917 meters
#    • Maximum incident distance: 8078811 meters
#
# 👥 TEAM RESPONSE PATTERNS:
#    • Average team size: 9.9 people
#    • Largest response: 81 people
#    • Average attendance rate: 68.1%
#
# ✅ DATA QUALITY:
#    • Geographic coordinate coverage: 100.0%
#    • Incidents with descriptions: 937 (100.0%)
#
# 💡 The interactive heatmap above shows the geographic distribution of incidents,
#    with red areas indicating higher concentrations of Search and Rescue activity.
# ============================================================
